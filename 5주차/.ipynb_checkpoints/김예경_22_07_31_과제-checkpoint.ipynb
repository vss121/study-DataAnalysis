# %% [markdown]
# ## 과제
# - mpg 데이터에 메서드 적용
# - 원리 설명

# %% [markdown]
# ##### 참고 https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

# %%
import pandas as pd

# %%
mpg = pd.read_csv('../mpg.csv')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
# 데이터프레임에서 하나의 열 시리즈로 추출
mpg_cty = mpg['cty']

# %%
mpg_cty
# Out:
# 0      18
# 1      21
# 2      20
# 3      21
# 4      16
#        ..
# 229    19
# 230    21
# 231    16
# 232    18
# 233    17
# Name: cty, Length: 234, dtype: int64

# %%
type(mpg_cty)
# Out:
# pandas.core.series.Series

# %%
mpg_hwy = mpg['hwy']

# %%
mpg_hwy
# Out:
# 0      29
# 1      29
# 2      31
# 3      30
# 4      26
#        ..
# 229    28
# 230    29
# 231    26
# 232    26
# 233    26
# Name: hwy, Length: 234, dtype: int64

# %% [markdown]
# 1. 시리즈에 사용하는 메서드(1.index 2.values 3.keys)

# %%
mpg.index # index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
mpg.values # values
# Out:
# array([['audi', 'a4', 1.8, ..., 29, 'p', 'compact'],
#        ['audi', 'a4', 1.8, ..., 29, 'p', 'compact'],
#        ['audi', 'a4', 2.0, ..., 31, 'p', 'compact'],
#        ...,
#        ['volkswagen', 'passat', 2.8, ..., 26, 'p', 'midsize'],
#        ['volkswagen', 'passat', 2.8, ..., 26, 'p', 'midsize'],
#        ['volkswagen', 'passat', 3.6, ..., 26, 'p', 'midsize']],
#       dtype=object)

# %%
mpg.keys # keys
# Out:
# <bound method NDFrame.keys of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# ...

# %%
mpg_cty.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
mpg_cty.values
# Out:
# array([18, 21, 20, 21, 16, 18, 18, 18, 16, 20, 19, 15, 17, 17, 15, 15, 17,
#        16, 14, 11, 14, 13, 12, 16, 15, 16, 15, 15, 14, 11, 11, 14, 19, 22,
#        18, 18, 17, 18, 17, 16, 16, 17, 17, 11, 15, 15, 16, 16, 15, 14, 13,
#        14, 14, 14,  9, 11, 11, 13, 13,  9, 13, 11, 13, 11, 12,  9, 13, 13,
#        12,  9, 11, 11, 13, 11, 11, 11, 12, 14, 15, 14, 13, 13, 13, 14, 14,
#        13, 13, 13, 11, 13, 18, 18, 17, 16, 15, 15, 15, 15, 14, 28, 24, 25,
#        23, 24, 26, 25, 24, 21, 18, 18, 21, 21, 18, 18, 19, 19, 19, 20, 20,
#        17, 16, 17, 17, 15, 15, 14,  9, 14, 13, 11, 11, 12, 12, 11, 11, 11,
#        12, 14, 13, 13, 13, 21, 19, 23, 23, 19, 19, 18, 19, 19, 14, 15, 14,
#        12, 18, 16, 17, 18, 16, 18, 18, 20, 19, 20, 18, 21, 19, 19, 19, 20,
#        20, 19, 20, 15, 16, 15, 15, 16, 14, 21, 21, 21, 21, 18, 18, 19, 21,
#        21, 21, 22, 18, 18, 18, 24, 24, 26, 28, 26, 11, 13, 15, 16, 17, 15,
# ...

# %%
mpg_cty.keys
# Out:
# <bound method Series.keys of 0      18
# 1      21
# 2      20
# 3      21
# 4      16
#        ..
# 229    19
# 230    21
# 231    16
# 232    18
# 233    17
# Name: cty, Length: 234, dtype: int64>

# %% [markdown]
# 2. append 2개 이상의 시리즈 연결

# %%
# Series
mpg_cty.append(mpg_hwy)
# Out:
# 0      18
# 1      21
# 2      20
# 3      21
# 4      16
#        ..
# 229    28
# 230    29
# 231    26
# 232    26
# 233    26
# Length: 468, dtype: int64

# %% [markdown]
# 3. describe 요약 통계

# %%
# DataFrame
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
# Series
mpg_cty.describe()
# Out:
# count    234.000000
# mean      16.858974
# std        4.255946
# min        9.000000
# 25%       14.000000
# 50%       17.000000
# 75%       19.000000
# max       35.000000
# Name: cty, dtype: float64

# %% [markdown]
# 4. drop_duplicates 중복 값이 없는 시리즈 반환

# %%
# DataFrame
mpg.drop_duplicates()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
# Series
mpg_cty.drop_duplicates()
# Out:
# 0      18
# 1      21
# 2      20
# 4      16
# 10     19
# 11     15
# 12     17
# 18     14
# 19     11
# 21     13
# 22     12
# 33     22
# 54      9
# 99     28
# 100    24
# 101    25
# 102    23
# 104    26
# 212    33
# 221    35
# 222    29
# Name: cty, dtype: int64

# %%
mpg.drop_duplicates(subset=['manufacturer']) # To remove duplicates on specific column(s), use subset.
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0           audi                  a4    1.8  1999    4    auto(l5)   f   18
# 18     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 37         dodge         caravan 2wd    2.4  1999    4    auto(l3)   f   18
# 74          ford      expedition 2wd    4.6  1999    8    auto(l4)   r   11
# 99         honda               civic    1.6  1999    4  manual(m5)   f   28
# 108      hyundai              sonata    2.4  1999    4    auto(l4)   f   18
# 122         jeep  grand cherokee 4wd    3.0  2008    6    auto(l5)   4   17
# 130   land rover         range rover    4.0  1999    8    auto(l4)   4   11
# 134      lincoln       navigator 2wd    5.4  1999    8    auto(l4)   r   11
# 137      mercury     mountaineer 4wd    4.0  1999    6    auto(l5)   4   14
# 141       nissan              altima    2.4  1999    4  manual(m5)   f   21
# ...

# %%
mpg.drop_duplicates(subset=['manufacturer','year'])
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0           audi                  a4    1.8  1999    4    auto(l5)   f   18
# 2           audi                  a4    2.0  2008    4  manual(m6)   f   20
# 18     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 21     chevrolet  c1500 suburban 2wd    5.7  1999    8    auto(l4)   r   13
# 37         dodge         caravan 2wd    2.4  1999    4    auto(l3)   f   18
# 41         dodge         caravan 2wd    3.3  2008    6    auto(l4)   f   17
# 74          ford      expedition 2wd    4.6  1999    8    auto(l4)   r   11
# 76          ford      expedition 2wd    5.4  2008    8    auto(l6)   r   12
# 99         honda               civic    1.6  1999    4  manual(m5)   f   28
# 104        honda               civic    1.8  2008    4  manual(m5)   f   26
# 108      hyundai              sonata    2.4  1999    4    auto(l4)   f   18
# ...

# %%
mpg.drop_duplicates(subset=['manufacturer','year'], keep='last') #To remove duplicates and keep last occurrences, use keep.
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 15          audi           a6 quattro    2.8  1999    6    auto(l5)   4   15
# 17          audi           a6 quattro    4.2  2008    8    auto(s6)   4   16
# 34     chevrolet               malibu    3.1  1999    6    auto(l4)   f   18
# 36     chevrolet               malibu    3.6  2008    6    auto(s6)   f   17
# 72         dodge  ram 1500 pickup 4wd    5.7  2008    8    auto(l5)   4   13
# 73         dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4   11
# 95          ford              mustang    4.6  1999    8  manual(m5)   r   15
# 98          ford              mustang    5.4  2008    8  manual(m6)   r   14
# 103        honda                civic    1.6  1999    4    auto(l4)   f   24
# 107        honda                civic    2.0  2008    4  manual(m6)   f   21
# 116      hyundai              tiburon    2.0  1999    4  manual(m5)   f   19
# ...

# %%
# Series
mpg_cty.drop_duplicates()
# Out:
# 0      18
# 1      21
# 2      20
# 4      16
# 10     19
# 11     15
# 12     17
# 18     14
# 19     11
# 21     13
# 22     12
# 33     22
# 54      9
# 99     28
# 100    24
# 101    25
# 102    23
# 104    26
# 212    33
# 221    35
# 222    29
# Name: cty, dtype: int64

# %%
mpg_hwy.drop_duplicates()
# Out:
# 0      29
# 2      31
# 3      30
# 4      26
# 6      27
# 8      25
# 9      28
# 15     24
# 17     23
# 18     20
# 19     15
# 21     17
# 28     19
# 29     14
# 39     22
# 45     21
# 49     18
# 54     12
# 61     16
# 99     33
# 100    32
# 104    34
# 105    36
# 195    35
# 196    37
# 212    44
# 222    41
# Name: hwy, dtype: int64

# %% [markdown]
# 5. equals 시리즈에 해당 값이 있는지 확인

# %%
mpg_cty.equals(mpg_hwy)
# Out:
# False

# %% [markdown]
# 6. get_values 시리즈 값 구하기( =values )
# - to_numpy()

# %%
mpg_cty.to_numpy()
# Out:
# array([18, 21, 20, 21, 16, 18, 18, 18, 16, 20, 19, 15, 17, 17, 15, 15, 17,
#        16, 14, 11, 14, 13, 12, 16, 15, 16, 15, 15, 14, 11, 11, 14, 19, 22,
#        18, 18, 17, 18, 17, 16, 16, 17, 17, 11, 15, 15, 16, 16, 15, 14, 13,
#        14, 14, 14,  9, 11, 11, 13, 13,  9, 13, 11, 13, 11, 12,  9, 13, 13,
#        12,  9, 11, 11, 13, 11, 11, 11, 12, 14, 15, 14, 13, 13, 13, 14, 14,
#        13, 13, 13, 11, 13, 18, 18, 17, 16, 15, 15, 15, 15, 14, 28, 24, 25,
#        23, 24, 26, 25, 24, 21, 18, 18, 21, 21, 18, 18, 19, 19, 19, 20, 20,
#        17, 16, 17, 17, 15, 15, 14,  9, 14, 13, 11, 11, 12, 12, 11, 11, 11,
#        12, 14, 13, 13, 13, 21, 19, 23, 23, 19, 19, 18, 19, 19, 14, 15, 14,
#        12, 18, 16, 17, 18, 16, 18, 18, 20, 19, 20, 18, 21, 19, 19, 19, 20,
#        20, 19, 20, 15, 16, 15, 15, 16, 14, 21, 21, 21, 21, 18, 18, 19, 21,
#        21, 21, 22, 18, 18, 18, 24, 24, 26, 28, 26, 11, 13, 15, 16, 17, 15,
# ...

# %%
mpg[mpg['manufacturer']=='hyundai']['cty'].to_numpy()
# Out:
# array([18, 18, 21, 21, 18, 18, 19, 19, 19, 20, 20, 17, 16, 17],
#       dtype=int64)

# %% [markdown]
# 7. isin 시리즈에 포함된 값이 있는지

# %%
mpg['manufacturer'].isin(['audi'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Name: manufacturer, Length: 234, dtype: bool

# %% [markdown]
# 8. min, max, mean, median

# %%
mpg_cty.min()
# Out:
# 9

# %%
mpg_cty.max()
# Out:
# 35

# %%
mpg_cty.mean()
# Out:
# 16.858974358974358

# %%
mpg_cty.median()
# Out:
# 17.0

# %% [markdown]
# 9. replace 특정 값을 가진 시리즈 값 교체

# %%
mpg['manufacturer'].replace('audi','**')
# Out:
# 0              **
# 1              **
# 2              **
# 3              **
# 4              **
#           ...
# 229    volkswagen
# 230    volkswagen
# 231    volkswagen
# 232    volkswagen
# 233    volkswagen
# Name: manufacturer, Length: 234, dtype: object

# %% [markdown]
# 10. sample 임의의 값 반환

# %%
mpg_cty.sample(n=10, random_state=1)
# Out:
# 199    13
# 69      9
# 233    17
# 39     16
# 138    13
# 174    16
# 90     18
# 67     13
# 119    17
# 73     11
# Name: cty, dtype: int64

# %%
mpg_hwy.sample(n=10, random_state=1)
# Out:
# 199    18
# 69     12
# 233    26
# 39     22
# 138    19
# 174    20
# 90     26
# 67     17
# 119    24
# 73     15
# Name: hwy, dtype: int64

# %% [markdown]
# 11. sort_values 정렬

# %%
mpg_cty.sort_values()
# Out:
# 59      9
# 54      9
# 69      9
# 65      9
# 126     9
#        ..
# 99     28
# 196    28
# 222    29
# 212    33
# 221    35
# Name: cty, Length: 234, dtype: int64

# %%
mpg_hwy.sort_values(ascending=False)
# Out:
# 221    44
# 212    44
# 222    41
# 196    37
# 105    36
#        ..
# 65     12
# 59     12
# 126    12
# 69     12
# 54     12
# Name: hwy, Length: 234, dtype: int64

# %% [markdown]
# 12. to_frame 시리즈 -> df로 반환

# %%
mpg_cty.to_frame()
# Out:
#      cty
# 0     18
# 1     21
# 2     20
# 3     21
# 4     16
# ..   ...
# 229   19
# 230   21
# 231   16
# 232   18
# 233   17
#
# [234 rows x 1 columns]

# %%
mpg_hwy.to_frame()
# Out:
#      hwy
# 0     29
# 1     29
# 2     31
# 3     30
# 4     26
# ..   ...
# 229   28
# 230   29
# 231   26
# 232   26
# 233   26
#
# [234 rows x 1 columns]
